# %% [markdown]
# <a href="https://colab.research.google.com/github/Tazagi-web/Kelvin-DS/blob/main/Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data=pd.read_csv('https://raw.githubusercontent.com/CourseMaterial/DataWrangling/main/flowerdataset.csv', header='infer')

data.head(8)

# %%
import pandas as pd

data2=pd.read_csv("annual-enterprise-survey-2023.csv",header="infer")

# %%
data.tail(6)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50979  2013                     Level 3                 ZZ11
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 50979  Food product manufacturing  Percentage           H36
# 50980  Food product manufacturing  Percentage           H37
# 50981  Food product manufacturing  Percentage           H38
# 50982  Food product manufacturing  Percentage           H39
# 50983  Food product manufacturing  Percentage           H40
# 50984  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# ...

# %%
# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc
# !pip install pypandoc
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   dvisvgm fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono
#   fonts-texgyre fonts-urw-base35 libapache-pom-java
#   libcmark-gfm-extensions0.29.0.gfm.3 libcmark-gfm0.29.0.gfm.3
#   libcommons-logging-java libcommons-parent-java libfontbox-java libgs9
#   libgs9-common libidn12 libijs-0.35 libjbig2dec0 libkpathsea6 libpdfbox-java
#   libptexenc1 libruby3.0 libsynctex2 libteckit0 libtexlua53 libtexluajit2
#   libwoff1 libzzip-0-13 lmodern pandoc-data poppler-data preview-latex-style
#   rake ruby ruby-net-telnet ruby-rubygems ruby-webrick ruby-xmlrpc ruby3.0
#   rubygems-integration t1utils teckit tex-common tex-gyre texlive-base
#   texlive-binaries texlive-fonts-recommended texlive-latex-base
#   texlive-latex-recommended texlive-pictures texlive-plain-generic tipa
#   xfonts-encodings xfonts-utils
# ...

# %%
import pandas as pd
data4=pd.read_csv('/annual-enterprise-survey-2023-financial-year-provisional.csv',header='infer')

data4.head(5)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2023                     Level 1                99999       All industries
# 1  2023                     Level 1                99999       All industries
# 2  2023                     Level 1                99999       All industries
# 3  2023                     Level 1                99999       All industries
# 4  2023                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
import pandas as pd
data6=pd.read_csv('/annual-enterprise-survey-2023-financial-year-provisional.csv',header='infer')

data6.head(8)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-4189184384> in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 data6=pd.read_csv('/annual-enterprise-survey-2023-financial-year-provisional.csv',header='infer')
#       3
#       4 data6.head(8)
#
# ...

# %%
import pandas as pd
data=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',header=None)

# %%
import pandas as pd
data6=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',header=None)
data.head(4)
data.sample

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd
data7=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',header=None)
data.sample(4)
data.shape
# Out:
# (150, 5)

# %%
data8.columns'sepal length','sepal width','petal length','petal width','class']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-2963443816> in <cell line: 0>()
# ----> 1 data8.columns['sepal length','sepal width','petal length','petal width','class']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5414                     )
#    5415
# -> 5416         result = getitem(key)
#    5417         # Because we ruled out integer above, we always get an arraylike here
#    5418         if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
import pandas as pd
data8=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',header=None)
data.sample(10)
# Out:
#        0    1    2    3                4
# 105  7.6  3.0  6.6  2.1   Iris-virginica
# 57   4.9  2.4  3.3  1.0  Iris-versicolor
# 40   5.0  3.5  1.3  0.3      Iris-setosa
# 79   5.7  2.6  3.5  1.0  Iris-versicolor
# 113  5.7  2.5  5.0  2.0   Iris-virginica
# 109  7.2  3.6  6.1  2.5   Iris-virginica
# 120  6.9  3.2  5.7  2.3   Iris-virginica
# 4    5.0  3.6  1.4  0.2      Iris-setosa
# 12   4.8  3.0  1.4  0.1      Iris-setosa
# 81   5.5  2.4  3.7  1.0  Iris-versicolor

# %%
data8.columns=['sepal length','sepal width','petal length','petal width','class']

# %%
data8
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.describe

data8
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from pandas.api.types import is_numeric_dtype

# %%
data8
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data['class'].value_counts()

# %%
data8
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
data8
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data['class'].hist()
# Out:
# <Axes: >

# %%
data['sepal length'].hist()
# Out:
# <Axes: >

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
print('\t mean=%.2f'%data['sepal length'].mean())
# Out:
# 	 mean=5.84

# %%
print('\t std=%.2f'%data['sepal length'].std())
# Out:
# 	 std=0.83

# %%
print('\t min=%.2f'%data['sepal length'].min())
# Out:
# 	 min=4.30

# %%
# !pip install pandas

# %%
import pandas as pd
data9=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None)

data9.head=(5)

# %% [markdown]
# #%% md
# ##Building a Linear Regression Model Using Data from an API
#
#
# ### understanding the linear Regression (Form 2 equation of a straight line)
#
# $y= mx + c$. Simple linear regression
#
#
# $y = β_0 + β_1X_0 + 𝝴$
#
#
# $y= 5 + (-40)X_0$
#
# API - Application programming interface (API)
#
# - Programs to communicate with each other
#
# - real time - histrical data
#
# AIM - Model how temperature depends on humidity or other factors - real world data
#
# $temperature = β_0 + β_1Humidity$
#
#
#
#
# - Simplest machine learning models
#
# some text -- for now -- data

# %% [markdown]
# pip install requests, pandas, skitlearn, matplotlib, seaborn

# %%
import requests
import pandas as pd
import time

# %%
API_KEY = '957da8aac6e362628ed22609227dd784'
BASE_URL = 'http://api.openweathermap.org/data/2.5/weather'

# %% [markdown]
# # List cities to collect data from

# %%
cities =['Nairobi', 'Kampala', 'Mombasa','Kisumu','Kigali','Johannesburg', 'Cairo','Lagos']

# %%
cities
# Out:
# ['Nairobi',
#  'Kampala',
#  'Mombasa',
#  'Kisumu',
#  'Kigali',
#  'Johannesburg',
#  'Cairo',
#  'Lagos']

# %% [markdown]
# # initialize to the empty list - weather data

# %%
weather_data = []

# %%
for city in cities:
    params = {
        'q': city,
        'appid': API_KEY,
        'units': 'metric'
    }
    response = requests.get(BASE_URL, params=params)

    if response.status_code == 200:
        data = response.json()
        weather_data.append({
            'city': city,
            'temperature': data['main']['temp'],
            'humidity': data['main']['humidity'],
            'pressure': data['main']['pressure'],
            'wind_speed': data['wind']['speed']
        })
    else:
        print(f"Failed to get data for {city}")

    # Pause to avoid hitting API rate limit
    time.sleep(1)

# Convert to DataFrame
df = pd.DataFrame(weather_data)
print(df)
# Out:
#            city  temperature  humidity  pressure  wind_speed
# 0       Nairobi        16.28        73      1019        0.56
# 1       Kampala        19.63        71      1015        1.55
# 2       Mombasa        24.32        83      1017        6.89
# 3        Kisumu        18.56        90      1016        1.48
# 4        Kigali        19.29        60      1017        3.09
# 5  Johannesburg         7.40        69      1028        1.62
# 6         Cairo        32.42        45      1006        4.63
# 7         Lagos        24.70        90      1013        3.18

# %%
df_store = pd.DataFrame(weather_data)
print(df)
# Out:
#            city  temperature  humidity  pressure  wind_speed
# 0       Nairobi        16.28        73      1019        0.56
# 1       Kampala        19.63        71      1015        1.55
# 2       Mombasa        24.32        83      1017        6.89
# 3        Kisumu        18.56        90      1016        1.48
# 4        Kigali        19.29        60      1017        3.09
# 5  Johannesburg         7.40        69      1028        1.62
# 6         Cairo        32.42        45      1006        4.63
# 7         Lagos        24.70        90      1013        3.18

# %%
df
# Out:
#            city  temperature  humidity  pressure  wind_speed
# 0       Nairobi        16.28        73      1019        0.56
# 1       Kampala        19.63        71      1015        1.55
# 2       Mombasa        24.32        83      1017        6.89
# 3        Kisumu        18.56        90      1016        1.48
# 4        Kigali        19.29        60      1017        3.09
# 5  Johannesburg         7.40        69      1028        1.62
# 6         Cairo        32.42        45      1006        4.63
# 7         Lagos        24.70        90      1013        3.18

# %% [markdown]
# ## Data clearning and preparation - > ML ready data
#
# - Missing data
#
# - Nulls remove them
#
# - Data preview

# %%
print(df.isnull().sum())
# Out:
# city           0
# temperature    0
# humidity       0
# pressure       0
# wind_speed     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#            city  temperature  humidity  pressure  wind_speed
# 0       Nairobi        16.28        73      1019        0.56
# 1       Kampala        19.63        71      1015        1.55
# 2       Mombasa        24.32        83      1017        6.89
# 3        Kisumu        18.56        90      1016        1.48
# 4        Kigali        19.29        60      1017        3.09
# 5  Johannesburg         7.40        69      1028        1.62
# 6         Cairo        32.42        45      1006        4.63
# 7         Lagos        24.70        90      1013        3.18

# %%
df.head()
# Out:
#       city  temperature  humidity  pressure  wind_speed
# 0  Nairobi        16.28        73      1019        0.56
# 1  Kampala        19.63        71      1015        1.55
# 2  Mombasa        24.32        83      1017        6.89
# 3   Kisumu        18.56        90      1016        1.48
# 4   Kigali        19.29        60      1017        3.09

# %%
df.tail()
# Out:
#            city  temperature  humidity  pressure  wind_speed
# 3        Kisumu        18.56        90      1016        1.48
# 4        Kigali        19.29        60      1017        3.09
# 5  Johannesburg         7.40        69      1028        1.62
# 6         Cairo        32.42        45      1006        4.63
# 7         Lagos        24.70        90      1013        3.18

# %%
df.sample(6)
# Out:
#            city  temperature  humidity  pressure  wind_speed
# 2       Mombasa        24.32        83      1017        6.89
# 3        Kisumu        18.56        90      1016        1.48
# 0       Nairobi        16.28        73      1019        0.56
# 7         Lagos        24.70        90      1013        3.18
# 5  Johannesburg         7.40        69      1028        1.62
# 4        Kigali        19.29        60      1017        3.09

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
#
# - basic statics
#
# - correlation analysis
#
# - Visualization

# %%
df_corr=df.drop('city', axis=1)

# %%
df_corr
# Out:
#    temperature  humidity  pressure  wind_speed
# 0        16.28        73      1019        0.56
# 1        19.63        71      1015        1.55
# 2        24.32        83      1017        6.89
# 3        18.56        90      1016        1.48
# 4        19.29        60      1017        3.09
# 5         7.40        69      1028        1.62
# 6        32.42        45      1006        4.63
# 7        24.70        90      1013        3.18

# %%
df_corr.corr()
# Out:
#              temperature  humidity  pressure  wind_speed
# temperature     1.000000 -0.240528 -0.953280    0.639940
# humidity       -0.240528  1.000000  0.274507   -0.101827
# pressure       -0.953280  0.274507  1.000000   -0.392582
# wind_speed      0.639940 -0.101827 -0.392582    1.000000

# %%
df.describe()
# Out:
#        temperature   humidity     pressure  wind_speed
# count      8.00000   8.000000     8.000000    8.000000
# mean      20.32500  72.625000  1016.375000    2.875000
# std        7.26515  15.352408     6.139742    2.069348
# min        7.40000  45.000000  1006.000000    0.560000
# 25%       17.99000  66.750000  1014.500000    1.532500
# 50%       19.46000  72.000000  1016.500000    2.355000
# 75%       24.41500  84.750000  1017.500000    3.542500
# max       32.42000  90.000000  1028.000000    6.890000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(df)
plt.show()

# %%
sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# #%% md
# ## Model building
#
# - selecting the features
#
# - Temp based on Humidity
#
# - Split the data -- 80% training and 20% testing
#
# $y = mx + c$

# %%
y=df['temperature']

# %%
y
# Out:
# 0    16.28
# 1    19.63
# 2    24.32
# 3    18.56
# 4    19.29
# 5     7.40
# 6    32.42
# 7    24.70
# Name: temperature, dtype: float64

# %%
x=df[['wind_speed']]

# %%
x
# Out:
#    wind_speed
# 0        0.56
# 1        1.55
# 2        6.89
# 3        1.48
# 4        3.09
# 5        1.62
# 6        4.63
# 7        3.18

# %% [markdown]
# # Spliting the data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2,
                                                    random_state=42)

# %%
X_train
# Out:
#    wind_speed
# 0        0.56
# 7        3.18
# 2        6.89
# 4        3.09
# 3        1.48
# 6        4.63

# %%
print(X_test)
# Out:
#    wind_speed
# 1        1.55
# 5        1.62

# %%
X_test
# Out:
#    wind_speed
# 1        1.55
# 5        1.62

# %%
y_train
# Out:
# 0    16.28
# 7    24.70
# 2    24.32
# 4    19.29
# 3    18.56
# 6    32.42
# Name: temperature, dtype: float64

# %%
y_test
# Out:
# 1    19.63
# 5     7.40
# Name: temperature, dtype: float64

# %% [markdown]
# #%% md
# # Building the Linear Regression Model

# %%
#%%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # initialize the model

# %%
lr_model=LinearRegression()

# %%
lr_model
# Out:
# LinearRegression()

# %% [markdown]
# #%%
# # training the model

# %%
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # check the coefficients

# %%
print(f'The intercept is {lr_model.intercept_}')
# Out:
# The intercept is 16.855076080805627

# %%
print(f'The coefficient is {lr_model.coef_}')
# Out:
# The coefficient is [1.73673946]

# %% [markdown]
# $Temperature = 1.73673946 *Windspeed + 16.855076080805627 $

# %% [markdown]
# # making predictions

# %%
y_pred=lr_model.predict(X_test)

# %%
y_pred
# Out:
# array([19.54702225, 19.66859401])

# %%
y_test
# Out:
# 1    19.63
# 5     7.40
# Name: temperature, dtype: float64

# %%
X_test
# Out:
#    wind_speed
# 1        1.55
# 5        1.62

# %%
(1.73673946*1.55) + 16.855076080805627
# Out:
# 19.54702224380563

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
print(f'The mean squared error is {mean_squared_error(y_test, y_pred)}')
# Out:
# The mean squared error is 75.26264211937797

# %%
print(f'The mean absolute error is {mean_absolute_error(y_test, y_pred)}')
# Out:
# The mean absolute error is 6.17578588114124

# %%
print(f'The r2 score is {r2_score(y_test, y_pred)}')
#
# Out:
# The r2 score is -1.0127347164995264

# %% [markdown]
# # results visualization

# %%
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.scatter(X_test, y_pred, color='red', label='Predicted')

plt.xlabel('wind_speed')
plt.ylabel('Temperature')
plt.title('Actual vs Predicted Temperature')
plt.legend()
plt.show()

# %% [markdown]
# # Regression Line

# %%
plt.scatter(df['wind_speed'],df['temperature'], color='blue')
plt.plot(df['wind_speed'], lr_model.predict(df[['wind_speed']]), color='red')
plt.xlabel('wind_speed')
plt.ylabel('Temperature')
plt.title('Actual vs Predicted Temperature')
plt.show()

# %% [markdown]
# # a) How good should the measure for evaluation be
# Wind is the best measure since the R2 is closer to 0.
# # b) others -
#
# ---
#
#
# Wind is the best measure for the model
# # c) Best
# Wind The r2 score is -1.0127347164995264
